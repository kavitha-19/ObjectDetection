# %%
import os
os.chdir('yolov5')

# %%
ls
# Out:
#  Volume in drive C is Acer
#  Volume Serial Number is 300F-3588
#
#  Directory of C:\Users\Kavitha padala\Desktop\kavithaProjects\objectdetection\Yolo_training\yolov5
#
# 05/10/2024  06:43 PM    <DIR>          .
# 05/10/2024  07:20 PM    <DIR>          ..
# 05/10/2024  03:18 PM             3,701 .dockerignore
# 05/10/2024  03:18 PM                75 .gitattributes
# 05/10/2024  03:18 PM    <DIR>          .github
# 05/10/2024  03:18 PM             3,998 .gitignore
# 05/10/2024  07:17 PM    <DIR>          .ipynb_checkpoints
# 05/10/2024  03:34 PM    <DIR>          __pycache__
# 05/10/2024  03:18 PM             8,064 benchmarks.py
# 05/10/2024  03:18 PM               393 CITATION.cff
# 05/10/2024  03:18 PM    <DIR>          classify
# 05/10/2024  03:18 PM             4,998 CONTRIBUTING.md
# 05/10/2024  03:18 PM    <DIR>          data
# 05/10/2024  03:38 PM               424 data.yaml
# 05/10/2024  03:40 PM    <DIR>          data_images
# 05/10/2024  03:18 PM            16,190 detect.py
# ...

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Using cached opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
#   Using cached pillow-10.3.0-cp311-cp311-win_amd64.whl.metadata (9.4 kB)
# ...
#   Using cached thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# ...
#   Using cached ultralytics-8.2.12-py3-none-any.whl.metadata (40 kB)
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached setuptools-69.5.1-py3-none-any.whl.metadata (6.2 kB)
# ...
#   Using cached py_cpuinfo-9.0.0-py3-none-any.whl.metadata (794 bytes)
# ...
#   Using cached matplotlib-3.8.4-cp311-cp311-win_amd64.whl.metadata (5.9 kB)
# ...
# Using cached opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl (38.6 MB)
# Using cached pillow-10.3.0-cp311-cp311-win_amd64.whl (2.5 MB)
# Using cached thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Using cached ultralytics-8.2.12-py3-none-any.whl (756 kB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached matplotlib-3.8.4-cp311-cp311-win_amd64.whl (7.7 MB)
# ...

# %%
import torch 

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
device
# Out:
# device(type='cuda', index=0)

# %%
# Training YOLO v5 model
# !python train.py --data data.yaml --cfg yolov5s.yaml --batch-size 8 --name Model --epochs 1 --device $device
# Out:
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# WARNING:tensorflow:From C:\Users\Kavitha padala\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# ...

# %%
# !python export.py --weights "C://Users//Kavitha padala//Desktop//kavithaProjects//objectdetection//Yolo_training//yolov5//runs//train//Model4//weights//best.pt" --include torchscript onnx
# Out:
# export: data=C:\Users\Kavitha padala\Desktop\kavithaProjects\objectdetection\Yolo_training\yolov5\data\coco128.yaml, weights=['C://Users//Kavitha padala//Desktop//kavithaProjects//objectdetection//Yolo_training//yolov5//runs//train//Model4//weights//best.pt'], imgsz=[640, 640], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, per_tensor=False, dynamic=False, simplify=False, opset=17, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['torchscript', 'onnx']
# YOLOv5  2024-5-10 Python-3.11.9 torch-2.2.2+cu121 CPU
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
#
# PyTorch: starting from C:\Users\Kavitha padala\Desktop\kavithaProjects\objectdetection\Yolo_training\yolov5\runs\train\Model4\weights\best.pt with output shape (1, 25200, 25) (13.8 MB)
#
# TorchScript: starting export with torch 2.2.2+cu121...
# ...
